# %% [markdown]
# # 检查metadata中数据信息

# %%
import numpy as np

australian_metadata = np.load('../origin_metadata/australian_lr_metadata.npy')
print(np.shape(australian_metadata))
process_australian_metadata = np.load('./process_australian_lr_metadata.npy')
process_classify_australian_metadata = np.load('.process_classify_australian_lr_metadata.npy')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-5e48aab6b470> in <module>()
#       1 import numpy as np
#       2
# ----> 3 australian_metadata = np.load('../origin_metadata/ethn_metadata.npy')
#       4 print(np.shape(australian_metadata))
#       5 process_australian_metadata = np.load('./process_australian_lr_metadata.npy')
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     413         own_fid = False
#     414     else:
# --> 415         fid = open(os_fspath(file), "rb")
#     416         own_fid = True
#     417
#
# FileNotFoundError: [Errno 2] No such file or directory: '../origin_metadata/ethn_metadata.npy'

# %% [markdown]
# ## (1)样本本身的信息 （共35维）
# 1. 数据集特征维度（属性维度）[0]
# 2. 已标记的数据集中正样本的比例，负样本的比例 [1, 2]
# 3. 根据当前模型的预测值，计算未标记数据集中，模型预测为正样本的比例，负样本的比例 [3, 4]

# %%
# print(australian_metadata[0:5, 0:5])
# print(australian_metadata[0:5, 396])
print(process_australian_metadata[0:5, 0:5])
print(process_australian_metadata[-5:-1, 0:5])
# print(process_australian_metadata[0:5, 396])
# Out:
# [[30.          0.5         0.5         0.51961722  0.48038278]
#  [30.          0.5         0.5         0.37511962  0.62488038]
#  [30.          0.5         0.5         0.38947368  0.61052632]
#  [30.          0.5         0.5         0.5492823   0.4507177 ]
#  [30.          0.5         0.5         0.12057416  0.87942584]]
# [[30.          0.55555556  0.44444444  0.57857858  0.42142142]
#  [30.          0.55555556  0.44444444  0.57357357  0.42642643]
#  [30.          0.55555556  0.44444444  0.57957958  0.42042042]
#  [30.          0.55555556  0.44444444  0.57957958  0.42042042]]

# %% [markdown]
# 1. 在整个数据集（包含已标记和未标记）中进行聚类，获取10个聚类中心点， [5, 15]
#
# 并按照每个中心点与x的距离从小到大排序记为 a_i  ⅈ=1,2,……10 (这10个点的顺序是根据不同的x变化的)。
#
# 计算x与上述10个代表性样本数据点的欧氏距离，并做归一化处理：
#
# (|(|x-a_i |)|^2-min⁡{|(|x_j-a_i |)|^2})/(max⁡{|(|x_j-a_i |)|^2}-min⁡{|(|x_j-a_i |)|^2}⁡).
#
# 其中x_j是在整个数据集范围内的。
#
#
#
# 2. 按照当前模型对已标记数据集的预测值进行排序，选出10等分点的数据 b_i  ⅈ=1,2,……10。 [15, 25]
#
# 计算x与上述10个代表性样本数据点的欧氏距离，并做归一化处理：
#
# (|(|x-b_i |)|^2-min⁡{|(|x_j-b_i |)|^2})/(max⁡{|(|x_j-b_i |)|^2}-min⁡{|(|x_j-b_i |)|^2}⁡).
#
# 其中x_j是在整个数据集范围内的。
#
#
#
# 3. 按照当前模型对未标记数据集的预测值进行排序，选出10等分点的数据 c_i  ⅈ=1,2,……10。 [25, 35]
#
# 计算x与上述10个代表性样本数据点的欧氏距离，并做归一化处理：
#
# (|(|x-c_i |)|^2-min⁡{|(|x_j-c_i |)|^2})/(max⁡{|(|x_j-c_i |)|^2}-min⁡{|(|x_j-c_i |)|^2}⁡).
#
# 其中x_j是在整个数据集范围内的。

# %%
print('*****a_i \n')
print(process_australian_metadata[0:5, 5:15])
print('*****b_i \n')
print(process_australian_metadata[0:5, 15:25])
print('*****c_i \n')
print(process_australian_metadata[0:5, 25:35])

# print(process_australian_metadata[0:5, 396])
# Out:
# *****a_i
#
# [[0.         0.14249646 0.16857254 0.19485845 0.41271767 0.47959849
#   0.51398936 0.66046835 0.74414627 1.        ]
#  [0.         0.12301938 0.13460455 0.24509353 0.3182114  0.41959084
#   0.73373931 0.87288368 0.92865109 1.        ]
#  [0.         0.26338858 0.35576088 0.53461229 0.62777735 0.65894068
#   0.66871589 0.73261527 0.76787671 1.        ]
#  [0.         0.11627186 0.20486031 0.24646665 0.29098348 0.35064998
#   0.57225152 0.66405758 0.76161033 1.        ]
#  [0.         0.16801393 0.22970166 0.24010843 0.24774685 0.68038006
#   0.89387953 0.89549206 0.91880735 1.        ]]
# *****b_i
#
# [[0.56744268 0.56744268 0.         0.50185491 0.63290869 0.56555949
#   0.56555949 0.63730672 0.57792006 1.        ]
#  [0.71533248 0.71533248 0.         0.48203034 0.64473653 0.66548646
#   0.66548646 0.62178048 0.80283624 1.        ]
#  [0.72673621 0.72673621 0.4858122  0.         0.50893519 0.38138934
#   0.38138934 0.59154643 0.70584249 1.        ]
#  [0.77066476 0.77066476 0.         0.72138768 0.81375763 0.72947224
#   0.72947224 0.78658024 0.73146033 1.        ]
#  [0.75342972 0.75342972 0.33635531 0.62670497 0.         0.53860002
#   0.53860002 0.53740899 0.69157666 1.        ]]
# *****c_i
#
# [[0.22586065 0.         0.10047569 0.2050777  0.07672719 0.49891427
#   0.1041691  0.32637798 0.42944046 1.        ]
#  [0.71351506 0.1776293  0.86239427 0.80497689 0.         0.42994439
#   0.81673915 0.52820491 0.4417616  1.        ]
#  [0.74809005 0.55128347 0.         0.215627   0.41033305 0.46972823
#   0.42999251 0.9253121  1.         0.82263873]
#  [0.37798561 0.07254281 0.19111308 0.         0.44412273 0.6373834
#   1.         0.05971854 0.36324608 0.57918188]
#  [0.8311185  0.73096164 0.34422011 0.         0.92778753 0.45504305
#   0.44902569 0.43417684 1.         0.43988434]]

# %% [markdown]
# ## (2)模型本身的信息，（共180维）
#
# 1)	在已标记数据上计算TP、FP、TN、FN的比例 (分别为连续的6个值）

# %%
print('第一轮的  \n',process_australian_metadata[0:10, [35, 41, 47, 53]])
print('第二轮的  \n',process_australian_metadata[0:10, [36, 42, 48, 54]])
print('第三轮的  \n',process_australian_metadata[0:10, [37, 43, 49, 55]])
print('第四轮的  \n',process_australian_metadata[0:10, [38, 44, 50, 56]])
print('第五轮的  \n',process_australian_metadata[0:10, [39, 45, 51, 57]])
print('第六轮的  \n',process_australian_metadata[0:10, [40, 46, 52, 58]])
# Out:
# 第一轮的
#  [[0.66666667 0.33333333 0.         0.        ]
#  [0.66666667 0.33333333 0.         0.        ]
#  [0.66666667 0.33333333 0.         0.        ]
#  [0.66666667 0.33333333 0.         0.        ]
#  [0.66666667 0.33333333 0.         0.        ]
#  [0.         0.         0.66666667 0.33333333]
#  [0.         0.         0.66666667 0.33333333]
#  [0.         0.         0.66666667 0.33333333]
#  [0.         0.         0.66666667 0.33333333]
#  [0.         0.         0.66666667 0.33333333]]
# 第二轮的
#  [[0.25 0.   0.5  0.25]
#  [0.25 0.   0.5  0.25]
#  [0.25 0.   0.5  0.25]
#  [0.25 0.   0.5  0.25]
#  [0.25 0.   0.5  0.25]
#  [0.   0.   0.75 0.25]
#  [0.   0.   0.75 0.25]
#  [0.   0.   0.75 0.25]
#  [0.   0.   0.75 0.25]
#  [0.   0.   0.75 0.25]]
# 第三轮的
#  [[0.6 0.4 0.  0. ]
#  [0.6 0.4 0.  0. ]
#  [0.6 0.4 0.  0. ]
#  [0.6 0.4 0.  0. ]
#  [0.6 0.4 0.  0. ]
#  [0.  0.  0.8 0.2]
#  [0.  0.  0.8 0.2]
#  [0.  0.  0.8 0.2]
#  [0.  0.  0.8 0.2]
#  [0.  0.  0.8 0.2]]
# 第四轮的
#  [[0.33333333 0.         0.5        0.16666667]
#  [0.33333333 0.         0.5        0.16666667]
#  [0.33333333 0.         0.5        0.16666667]
#  [0.33333333 0.         0.5        0.16666667]
#  [0.33333333 0.         0.5        0.16666667]
#  [0.         0.         0.66666667 0.33333333]
#  [0.         0.         0.66666667 0.33333333]
#  [0.         0.         0.66666667 0.33333333]
#  [0.         0.         0.66666667 0.33333333]
#  [0.         0.         0.66666667 0.33333333]]
# 第五轮的
#  [[0.57142857 0.42857143 0.         0.        ]
#  [0.57142857 0.42857143 0.         0.        ]
#  [0.57142857 0.42857143 0.         0.        ]
#  [0.57142857 0.42857143 0.         0.        ]
#  [0.57142857 0.42857143 0.         0.        ]
#  [0.         0.         0.57142857 0.42857143]
#  [0.         0.         0.57142857 0.42857143]
#  [0.         0.         0.57142857 0.42857143]
#  [0.         0.         0.57142857 0.42857143]
#  [0.         0.         0.57142857 0.42857143]]
# 第六轮的
#  [[0.5   0.    0.5   0.   ]
#  [0.5   0.    0.5   0.   ]
#  [0.5   0.    0.5   0.   ]
#  [0.5   0.125 0.375 0.   ]
#  [0.375 0.    0.5   0.125]
#  [0.25  0.    0.5   0.25 ]
#  [0.375 0.    0.5   0.125]
#  [0.375 0.    0.5   0.125]
#  [0.375 0.    0.5   0.125]
#  [0.375 0.    0.5   0.125]]

# %% [markdown]
# 2) 在已标记数据上按照当前模型对已标记数据集的预测值做归一化处理（在整个数据集上选出最小最大值进行归一化），并进行排序，选出10等分点的值记录

# %%
print('第一轮的  \n',process_australian_metadata[0:10, 59:69])
print('第二轮的  \n',process_australian_metadata[0:10, 69:79])
print('第三轮的  \n',process_australian_metadata[0:10, 79:89])
print('第四轮的  \n',process_australian_metadata[0:10, 89:99])
print('第五轮的  \n',process_australian_metadata[0:10, 99:109])
print('第六轮的  \n',process_australian_metadata[0:10, 109:119])
# Out:
# 第一轮的
#  [[0.         0.         0.         0.         0.37791514 0.37791514
#   0.37791514 1.         1.         1.        ]
#  [0.         0.         0.         0.         0.37791514 0.37791514
#   0.37791514 1.         1.         1.        ]
#  [0.         0.         0.         0.         0.37791514 0.37791514
#   0.37791514 1.         1.         1.        ]
#  [0.         0.         0.         0.         0.37791514 0.37791514
#   0.37791514 1.         1.         1.        ]
#  [0.         0.         0.         0.         0.37791514 0.37791514
#   0.37791514 1.         1.         1.        ]
#  [0.         0.         0.         0.         0.00920208 0.00920208
#   0.00920208 1.         1.         1.        ]
#  [0.         0.         0.         0.         0.00920208 0.00920208
#   0.00920208 1.         1.         1.        ]
#  [0.         0.         0.         0.         0.00920208 0.00920208
#   0.00920208 1.         1.         1.        ]
#  [0.         0.         0.         0.         0
print('第三轮的  \n',process_australian_metadata[0:10, [121, 127]])
print('第四轮的  \n',process_australian_metadata[0:10, [122, 128]])
print('第五轮的  \n',process_australian_metadata[0:10, [123, 129]])
print('第六轮的  \n',process_australian_metadata[0:10, [124, 130]])
# Out:
# 第一轮的
#  [[0.41337454 0.41468958]
#  [0.41337454 0.41468958]
#  [0.41337454 0.41468958]
#  [0.41337454 0.41468958]
#  [0.41337454 0.41468958]
#  [0.30276062 0.45646622]
#  [0.30276062 0.45646622]
#  [0.30276062 0.45646622]
#  [0.30276062 0.45646622]
#  [0.30276062 0.45646622]]
# 第二轮的
#  [[0.40717497 0.35701986]
#  [0.40717497 0.35701986]
#  [0.40717497 0.35701986]
#  [0.40717497 0.35701986]
#  [0.40717497 0.35701986]
#  [0.36645855 0.34821952]
#  [0.36645855 0.34821952]
#  [0.36645855 0.34821952]
#  [0.36645855 0.34821952]
#  [0.36645855 0.34821952]]
# 第三轮的
#  [[0.55630322 0.34360355]
#  [0.55630322 0.34360355]
#  [0.55630322 0.34360355]
#  [0.55630322 0.34360355]
#  [0.55630322 0.34360355]
#  [0.42099258 0.32363205]
#  [0.42099258 0.32363205]
#  [0.42099258 0.32363205]
#  [0.42099258 0.32363205]
#  [0.42099258 0.32363205]]
# 第四轮的
#  [[0.4074211  0.29733812]
#  [0.4074211  0.29733812]
#  [0.4074211  0.29733812]
#  [0.4074211  0.29733812]
#  [0.4074211  0.29733812]
#  [0.38343727 0.27495985]
#  [0.38343727 0.27495985]
#  [0.38343727 0.27495985]
#  [0.38343727 0.27495985]
#  [0.38343727 0.27495985]]
# 第五轮的
#  [[0.52670348 0.34065141]
#  [0.52670348 0.34065141]
#  [0.52670348 0.34065141]
#  [0.52670348 0.34065141]
#  [0.52670348 0.34065141]
#  [0.38398318 0.27338086]
#  [0.38398318 0.27338086]
#  [0.38398318 0.27338086]
#  [0.38398318 0.27338086]
#  [0.38398318 0.27338086]]
# 第六轮的
#  [[0.41081245 0.30757444]
#  [0.43718198 0.32545405]
#  [0.4304241  0.30246014]
#  [0.45977301 0.31366476]
#  [0.44613082 0.3041529 ]
#  [0.36519845 0.30780499]
#  [0.4135375  0.33932829]
#  [0.41190019 0.29357196]
#  [0.38673308 0.29941278]
#  [0.37234999 0.30907142]]

# %% [markdown]
# 4) 在未标记数据上，根据当前模型的预测值，计算未标记数据集中，模型预测为正样本的比例，负样本的比例 [131, 142]

# %%
print('第一轮的  \n',process_australian_metadata[0:10, [131, 137]])
print('第二轮的  \n',process_australian_metadata[0:10, [132, 138]])
print('第三轮的  \n',process_australian_metadata[0:10, [133, 139]])
print('第四轮的  \n',process_australian_metadata[0:10, [134, 140]])
print('第五轮的  \n',process_australian_metadata[0:10, [135, 141]])
print('第六轮的  \n',process_australian_metadata[0:10, [136, 142]])
# Out:
# 第一轮的
#  [[0.51904762 0.48095238]
#  [0.3752381  0.6247619 ]
#  [0.38952381 0.61047619]
#  [0.54857143 0.45142857]
#  [0.12190476 0.87809524]
#  [0.01904762 0.98095238]
#  [0.13619048 0.86380952]
#  [0.12952381 0.87047619]
#  [0.19047619 0.80952381]
#  [0.16285714 0.83714286]]
# 第二轮的
#  [[0.51954242 0.48045758]
#  [0.37559581 0.62440419]
#  [0.38989514 0.61010486]
#  [0.54909438 0.45090562]
#  [0.12202097 0.87797903]
#  [0.01906578 0.98093422]
#  [0.13632031 0.86367969]
#  [0.12964728 0.87035272]
#  [0.19065777 0.80934223]
#  [0.16301239 0.83698761]]
# 第三轮的
#  [[0.51908397 0.48091603]
#  [0.375      0.625     ]
#  [0.38931298 0.61068702]
#  [0.54866412 0.45133588]
#  [0.12118321 0.87881679]
#  [0.01908397 0.98091603]
#  [0.13645038 0.86354962]
#  [0.12977099 0.87022901]
#  [0.19083969 0.80916031]
#  [0.16316794 0.83683206]]
# 第四轮的
#  [[0.51957975 0.48042025]
#  [0.37535817 0.62464183]
#  [0.38968481 0.61031519]
#  [0.54918816 0.45081184]
#  [0.12129895 0.87870105]
#  [0.0191022  0.9808978 ]
#  [0.1356256  0.8643744 ]
#  [0.12893983 0.87106017]
#  [0.19006686 0.80993314]
#  [0.16236867 0.83763133]]
# 第五轮的
#  [[0.51912046 0.48087954]
#  [0.37476099 0.62523901]
#  [0.38910134 0.61089866]
#  [0.54875717 0.45124283]
#  [0.12045889 0.87954111]
#  [0.01912046 0.98087954]
#  [0.13575526 0.86424474]
#  [0.1290631  0.8709369 ]
#  [0.19024857 0.80975143]
#  [0.1625239  0.8374761 ]]
# 第六轮的
#  [[0.51961722 0.48038278]
#  [0.37511962 0.62488038]
#  [0.38947368 0.61052632]
#  [0.5492823  0.4507177 ]
#  [0.12057416 0.87942584]
#  [0.01818182 0.98181818]
#  [0.13492823 0.86507177]
#  [0.12822967 0.87177033]
#  [0.18947368 0.81052632]
#  [0.16172249 0.83827751]]

# %% [markdown]
# 5) 按照当前模型对未标记数据集的预测值做归一化处理（在整个数据集上选出最小最大值进行归一化），并进行排序，选出10等分点的值记录

# %%
print('第一轮的  \n',process_australian_metadata[0:10, 143:153])
print('第一轮的  \n',np.sum(process_australian_metadata[0, 143:153]))

print('第二轮的  \n',process_australian_metadata[0:10, 153:163])
print('第三轮的  \n',process_australian_metadata[0:10, 163:173])
print('第四轮的  \n',process_australian_metadata[0:10, 173:183])
print('第五轮的  \n',process_australian_metadata[0:10, 183:193])
print('第六轮的  \n',process_australian_metadata[0:10, 193:203])
# Out:
# 第一轮的
#  [[0.         0.31116976 0.36722048 0.41153099 0.44358826 0.48188235
#   0.5204313  0.56268452 0.61001591 0.68817521]
#  [0.         0.31116976 0.36722048 0.41153099 0.44358826 0.48188235
#   0.5204313  0.56268452 0.61001591 0.68817521]
#  [0.         0.31116976 0.36722048 0.41153099 0.44358826 0.48188235
#   0.5204313  0.56268452 0.61001591 0.68817521]
#  [0.         0.31116976 0.36722048 0.41153099 0.44358826 0.48188235
#   0.5204313  0.56268452 0.61001591 0.68817521]
#  [0.         0.31116976 0.36722048 0.41153099 0.44358826 0.48188235
#  [0.         0.26769492 0.31806709 0.35353326 0.38523113 0.41242728
#   0.44566331 0.48240051 0.53899619 0.62729763]
#  [0.         0.26358883 0.32304744 0.3612055  0.38788766 0.41679247
#   0.44288329 0.4802698  0.52561735 0.62837   ]
#  [0.         0.25704333 0.31357022 0.34920874 0.37793188 0.4121795
#   0.44534995 0.48540232 0.53960234 0.62210402]
#  [0.         0.19784758 0.23646943 0.26817495 0.29537804 0.32673093
#   0.35821834 0.40312343 0.44662279 0.51365409]
#  [0.         0.21166598 0.23640962 0.25761578 0.28491207 0.31198394
#   0.34096723 0.36861314 0.40953221 0.47029058]
#  [0.         0.23551295 0.27175645 0.30044451 0.33253263 0.3615313
#   0.38604941 0.41864414 0.45686024 0.51336986]
#  [0.         0.21515931 0.25554463 0.28510489 0.31737397 0.34838225
#   0.37935762 0.41452625 0.45502072 0.51366094]
#  [0.         0.21807959 0.26046316 0.28555619 0.30634443 0.32503415
#   0.35079528 0.38072149 0.4191259  0.47461954]]

# %% [markdown]
# 6)	计算5)中10个值的均值和方差

# %%
print('第一轮的  \n',process_australian_metadata[0:10, [203, 209]])
print('第二轮的  \n',process_australian_metadata[0:10, [204, 210]])
print('第三轮的  \n',process_australian_metadata[0:10, [205, 211]])
print('第四轮的  \n',process_australian_metadata[0:10, [206, 212]])
print('第五轮的  \n',process_australian_metadata[0:10, [207, 213]])
print('第六轮的  \n',process_australian_metadata[0:10, [208, 214]])
# Out:
# 第一轮的
#  [[0.43966988 0.18168311]
#  [0.43966988 0.18168311]
#  [0.43966988 0.18168311]
#  [0.43966988 0.18168311]
#  [0.43966988 0.18168311]
#  [0.34061148 0.13275807]
#  [0.34061148 0.13275807]
#  [0.34061148 0.13275807]
#  [0.34061148 0.13275807]
#  [0.34061148 0.13275807]]
# 第二轮的
#  [[0.31092023 0.1300443 ]
#  [0.31092023 0.1300443 ]
#  [0.31092023 0.1300443 ]
#  [0.31092023 0.1300443 ]
#  [0.31092023 0.1300443 ]
#  [0.40980845 0.1573142 ]
#  [0.40980845 0.1573142 ]
#  [0.40980845 0.1573142 ]
#  [0.40980845 0.1573142 ]
#  [0.40980845 0.1573142 ]]
# 第三轮的
#  [[0.46226146 0.18889317]
#  [0.46226146 0.18889317]
#  [0.46226146 0.18889317]
#  [0.46226146 0.18889317]
#  [0.46226146 0.18889317]
#  [0.40936968 0.15954889]
#  [0.40936968 0.15954889]
#  [0.40936968 0.15954889]
#  [0.40936968 0.15954889]
#  [0.40936968 0.15954889]]
# 第四轮的
#  [[0.32794561 0.14130613]
#  [0.32794561 0.14130613]
#  [0.32794561 0.14130613]
#  [0.32794561 0.14130613]
#  [0.32794561 0.14130613]
#  [0.39630822 0.15731523]
#  [0.39630822 0.15731523]
#  [0.39630822 0.15731523]
#  [0.39630822 0.15731523]
#  [0.39630822 0.15731523]]
# 第五轮的
#  [[0.45599251 0.18635703]
#  [0.45599251 0.18635703]
#  [0.45599251 0.18635703]
#  [0.45599251 0.18635703]
#  [0.45599251 0.18635703]
#  [0.28447283 0.12628046]
#  [0.28447283 0.12628046]
#  [0.28447283 0.12628046]
#  [0.28447283 0.12628046]
#  [0.28447283 0.12628046]]
# 第六轮的
#  [[0.35432335 0.15091534]
#  [0.3945877  0.16682882]
#  [0.38313113 0.16240779]
#  [0.38296623 0.1611759 ]
#  [0.38023923 0.16290676]
#  [0.30462196 0.13681246]
#  [0.28919906 0.12256834]
#  [0.32767015 0.13555712]
#  [0.31841306 0.13701996]
#  [0.30207397 0.12364699]]

# %% [markdown]
# 7)	将在此轮之前的五轮主动学习过程中，上述1)到6)的特征全部用作本轮的特征

# %% [markdown]
# ## (3)模型在样本上预测的信息（共181维）
#
# 根据当前模型对整个数据集的预测值，做归一化处理
#
# （注意a、b、c三组样本都是本轮选出来的，而不是前5轮选出的）
#
# 1) 记录f(x)

# %%
print(process_australian_metadata[0:10, 215])
# Out:
# [-0.01881138 -0.01833974 -0.00632963 -0.01094446 -0.01346968  0.001377
#   0.01123321  0.00600977  0.00489726  0.00991839]

# %% [markdown]
# 2)	计算与a，b，c三组共30个样本预测值的差（不是绝对值）。

# %%
print('第一轮的  \n a : \n',process_australian_metadata[0:10, 216:226])
print('b:  \n',process_australian_metadata[0:10, 226:236])
print('c:  \n',process_australian_metadata[0:10, 236:246])
# print('第二轮的  \n a : \n',process_australian_metadata[0:10, 246:226])
# print('第二轮的  b:  \n',process_australian_metadata[0:10, 226:236])
# print('第二轮的  c:  \n',process_australian_metadata[0:10, 236:246])
# print('第三轮的  \n a : \n',process_australian_metadata[0:10, 216:226])
# print('第三轮的  b:  \n',process_australian_metadata[0:10, 226:236])
# print('第三轮的  c:  \n',process_australian_metadata[0:10, 236:246])
# print('第四轮的  \n a : \n',process_australian_metadata[0:10, 216:226])
# print('第四轮的  b:  \n',process_australian_metadata[0:10, 226:236])
# print('第四轮的  c:  \n',process_australian_metadata[0:10, 236:246])
# print('第五轮的  \n a : \n',process_australian_metadata[0:10, 216:226])
# print('第五轮的  b:  \n',process_australian_metadata[0:10, 226:236])
# print('第五轮的  c:  \n',process_australian_metadata[0:10, 236:246])
# print('第六轮的  \n a : \n',process_australian_metadata[0:10, 216:226])
# print('第六轮的  b:  \n',process_australian_metadata[0:10, 226:236])
# print('第六轮的  c:  \n',process_australian_metadata[0:10, 236:246])
# Out:
# 第一轮的
#  a :
#  [[-0.19683997 -0.20347343 -0.20394236 -0.22890754 -0.24497698 -0.18562231
#   -0.13379711 -0.3817883  -0.28014453 -0.34661927]
#  [-0.05746812 -0.05793705 -0.23578299 -0.08290223  0.0122082  -0.09897167
#   -0.05083466 -0.039617   -0.13413922 -0.20061396]
#  [-0.03518544 -0.00975134 -0.01022026 -0.05125489 -0.08642244  0.00809978
#   -0.00311787 -0.18806621  0.05992498 -0.15289718]
#  [-0.05592064 -0.05545171 -0.04881825 -0.08088582  0.01422461 -0.03760059
#   -0.09695526 -0.23376658 -0.13212281 -0.19859755]
#  [ 0.22353627  0.18203273  0.0452214   0.19810217  0.22306735  0.23016974
#    0.29321259  0.24138739  0.08039043  0.14686517]
#    0.10543738  0.16113093  0.1698692   0.0721936 ]
#  [-0.13307417 -0.15523734 -0.11031677 -0.03886571 -0.09045876 -0.12149057
#   -0.1407971  -0.09455927 -0.12780305 -0.03012745]
#  [-0.04973449 -0.08076629 -0.06959249 -0.05383499 -0.10007282 -0.09234989
#   -0.11451306  0.00185857  0.01059683 -0.08707877]
#  [-0.08785418 -0.10771218 -0.09195468 -0.03626112 -0.13046958 -0.11888598
#   -0.13819251 -0.15263275 -0.02752286 -0.12519846]
#  [-0.0951895  -0.10636329 -0.02373844 -0.07533149 -0.11267578 -0.07943199
#   -0.12566982 -0.01500017 -0.11794689 -0.14011006]]

# %% [markdown]
# 3)	将在此轮之前的五轮主动学习过程中，上述1)到2）的特征全部用作本轮的特征

# %% [markdown]
# ## 查看metadata的（y）性能提升

# %%
improve_accuracy_max = np.max(process_australian_metadata[:, 396])
improve_accuracy_min = np.min(process_australian_metadata[:, 396])
print('improve_accuracy_max:  ', improve_accuracy_max)
print('improve_accuracy_min:  ', improve_accuracy_min)

improve_accuracy_mean = np.mean(process_australian_metadata[:, 396])
improve_accuracy_std = np.std(process_australian_metadata[:, 396])
print('improve_accuracy_mean:  ', improve_accuracy_mean)
print('improve_accuracy_std:  ', improve_accuracy_std)

postive_improve_accuracy_mean = np.mean(process_australian_metadata[np.where(process_australian_metadata[:, 396]>0)[0], 396])
postive_improve_accuracy_std = np.std(process_australian_metadata[np.where(process_australian_metadata[:, 396]>0)[0], 396])
print('postive_improve_accuracy_mean:  ', postive_improve_accuracy_mean)
print('postive_improve_accuracy_std:  ', postive_improve_accuracy_std)

negative_improve_accuracy_mean = np.mean(process_australian_metadata[np.where(process_australian_metadata[:, 396]<0)[0], 396])
negative_improve_accuracy_std = np.std(process_australian_metadata[np.where(process_australian_metadata[:, 396]<0)[0], 396])
print('negative_improve_accuracy_mean:  ', negative_improve_accuracy_mean)
print('negative_improve_accuracy_std:  ', negative_improve_accuracy_std)
# Out:
# improve_accuracy_max:   0.39124920735573876
# improve_accuracy_min:   -0.3024730500951174
# improve_accuracy_mean:   0.029865706664491825
# improve_accuracy_std:   0.09358214768887047
# postive_improve_accuracy_mean:   0.09039050319363723
# postive_improve_accuracy_std:   0.07812663688000544
# negative_improve_accuracy_mean:   -0.047210492043581145
# negative_improve_accuracy_std:   0.039133584786268195

# %%
from sklearn.externals import joblib
rfr = joblib.load('./rfr_p_regression_wdbc.joblib')
feature_importance = rfr.feature_importances_
print(np.shape(feature_importance))
print(np.argmax(feature_importance ))

# print(np.argsort(feature_importance))

# print(feature_importance)
import matplotlib.pyplot as plt

x = np.arange(0,396)
plt.scatter(x, feature_importance)
plt.show()
# Out:
# (396,)
# 185

# %%
print(len(np.where(process_classify_australian_metadata>0)[0]))
print(len(np.where(process_classify_australian_metadata<0)[0]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-374a9e2da790> in <module>()
# ----> 1 print(len(np.where(process_classify_australian_metadata>0)[0]))
#       2 print(len(np.where(process_classify_australian_metadata<0)[0]))
#
# NameError: name 'np' is not defined
