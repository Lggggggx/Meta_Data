# %%
import numpy as np 
import torch
import torch.utils.data as Data
import torch.optim as optim

from MyNet import Net, MetaDataSet, MyLoss

# hyper parameters
BATCH_SIZE = 10
EPOCH_SIZE = 10

LR = 1e-3
MOMENTUM = 0.9
WEIGHT_DECAY =  0.0005

DATASET_SHUFFLE = False
num_WORKERS = 2

TASK = 'regression'

XI = 0.0001

save_path = './'
metadata_dir = 'E:/metadata数据集/new_bigmetadata/australian/query_time/'

# net = Net(n_feature=396, first_n_hidden=100, second_n_hidden=20, n_output=2)
net_bn = Net(n_feature=836, first_n_hidden=200, second_n_hidden=100, n_output=1, batch_normalization=True)
net_no_bn = Net(n_feature=836, first_n_hidden=200, second_n_hidden=100, n_output=1, batch_normalization=False)

nets = [net_bn, net_no_bn]
optimizers = [optim.Adam(net.parameters(), lr=LR, weight_decay=WEIGHT_DECAY) for net in nets]
criterion = MyLoss(XI)
print(nets)
print(optimizers)
print(criterion)
# Out:
# [Net(
#   (input_bn): BatchNorm1d(418, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (first_hidden): Linear(in_features=418, out_features=200, bias=True)
#   (first_bn): BatchNorm1d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (second_hidden): Linear(in_features=200, out_features=100, bias=True)
#   (second_bn): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (out): Linear(in_features=100, out_features=1, bias=True)
# ), Net(
#   (input_bn): BatchNorm1d(418, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (first_hidden): Linear(in_features=418, out_features=200, bias=True)
#   (first_bn): BatchNorm1d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (second_hidden): Linear(in_features=200, out_features=100, bias=True)
#   (second_bn): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (out): Linear(in_features=100, out_features=1, bias=True)
# )]
# [Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0.0005
# ), Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0.0005
# )]
# MyLoss()

# %%
# print('Preparing the dataset....')
# loader = MetaDataSet(metadata_dir, BATCH_SIZE, num_WORKERS, TASK)
# print("Dataset is ready!")

metadata = np.load('E:/metadata数据集/new_bigmetadata/australian/query_time/2australian30_big_metadata30.npy')

# X = metadata[:, 0:396]
# y = metadata[:, 396]
X = metadata[:, 0:418]
y = metadata[:, 418]
# y[np.where(y>0)[0]] = 1
# y[np.where(y<=0)[0]] = 0

X_tensor = torch.from_numpy(X)
y_tensor = torch.from_numpy(y)
X_tensor = X_tensor.float()
y_tensor = y_tensor.float()
print(torch.max(y_tensor))
print(torch.min(y_tensor))
print(torch.mean(y_tensor))

print(torch.min(torch.abs(y_tensor)))

print(X_tensor.dtype)
print(y_tensor.dtype)
# troch_dataset = Data.TensorDataset(data_tensor=X_tensor, target_tensor=y_tensor)
troch_dataset = Data.TensorDataset(X_tensor, y_tensor)

loader = Data.DataLoader(dataset=troch_dataset,
                        batch_size=BATCH_SIZE,
                        shuffle=DATASET_SHUFFLE,
                        num_workers=3)
# Out:
# tensor(0.0814)
# tensor(-0.0494)
# tensor(0.0007)
# tensor(0.)
# torch.float32
# torch.float32

# %%
# tarining the NN
for epoch in range(EPOCH_SIZE):
    running_loss0 = 0.0
    running_loss1 = 0.0
    for step, (batch_x, batch_y) in enumerate(loader):
        print('the shape of batch_X', batch_x.size())
        print('the shape of batch_y', batch_y.size())

        for net, optimizer in zip(nets, optimizers):
            optimizer.zero_grad()
            outputs = net(batch_x)
            loss = criterion(outputs, batch_y)
            print('the dtype of loss ', loss.dtype)
            print('the shape of loss', loss.size())
            print('len of loss ', loss)
            loss.backward()
            optimizer.step()
            
            if net == nets[0]:
                i = 0
                # print statistics
                running_loss0 += loss.item()
                # print every 2000 mini-batches
                if step % 1000 == 999:    
                    print('net',i,' [%d, %5d] loss: %.3f' %
                        (epoch + 1, step + 1, running_loss0 / 2000))
                    running_loss0 = 0.0
            else:
                i = 1
                # print statistics
                running_loss1 += loss.item()
                # print every 2000 mini-batches
                if step % 1000 == 999:    
                    print('net',i,' [%d, %5d] loss: %.3f' %
                        (epoch + 1, step + 1, running_loss1 / 2000))
                    running_loss1 = 0.0

# save the parameters in NN
torch.save({
            'model_state_dict': nets[0].state_dict(),
            'optimizer_state_dict': optimizers[0].state_dict(),
            }, './regression_bn_net_parameters.pth')
torch.save({
            'model_state_dict': nets[1].state_dict(),
            'optimizer_state_dict': optimizers[1].state_dict(),
            }, './regression_nobn_net_parameters.pth')
# Out:
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\loss.py:443: UserWarning: Using a target size (torch.Size([10])) that is different to the input size (torch.Size([10, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(10.3720, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(10.1652, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(10.3137, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(10.4393, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(8.0996, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(8.0712, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(7.1646, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(6.8983, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(23.8698, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(24.2827, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(19.0551, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(19.1172, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(6.2155, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(6.2312, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(17.4281, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(17.5784, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(11.4622, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(11.4349, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(9.4590, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(9.2952, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(18.8196, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(18.9229, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(21.2302, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(21.1458, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(9.2703, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(9.1105, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(8.6109, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(8.6987, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(13.0559, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(13.2581, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(19.8104, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(19.8276, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(3.9700, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(4.0135, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(4.7064, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(4.5800, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(60.2278, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(60.4981, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(24.1442, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(24.2244, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(8.7835, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(8.8467, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(5.2930, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(5.2195, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(1.9442, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(1.8746, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(8.0111, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(7.9620, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(7.8449, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(7.9243, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(7.4137, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(7.3086, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(7.4202, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(7.3916, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(29.2680, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(29.2642, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(31.9156, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(32.1101, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(4.2950, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(4.2011, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(9.8090, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(9.8925, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(20.9495, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(20.9605, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(19.4787, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(19.5754, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(26.9724, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(27.0131, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(17.2137, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(17.1607, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(6.7304, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(6.6645, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(11.7029, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(11.7108, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(7.9042, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(7.8498, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(19.9902, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(20.0521, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(19.5689, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(19.6310, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(15.6574, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(15.7030, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(37.9615, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(37.9994, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(28.4795, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(28.4692, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(9.2255, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(9.2244, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(7.1663, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(7.1834, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(6.1616, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(6.1555, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(7.8284, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(7.8294, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(8.3776, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(8.3692, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(31.3101, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(31.3097, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(15.4970, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(15.5056, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(13.5707, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(13.5724, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(8.3668, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(8.3679, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(17.2216, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(17.2316, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(5.8828, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(5.8625, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(8.2401, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(8.2122, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(8.9123, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(8.8848, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(3.5281, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(3.5104, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(12.0085, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(11.9654, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(14.0575, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(14.0542, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(14.9573, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(14.9299, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(9.8472, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(9.8959, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(22.4327, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(22.4610, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(21.3045, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(21.5097, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(3.0777, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(3.0289, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(13.9839, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(14.0567, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(10.2175, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(10.1839, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(14.3137, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(14.2996, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(9.3154, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(9.3101, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(18.2731, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(18.1075, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(6.3787, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(6.3183, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(10.8151, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(10.8219, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(13.0249, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(13.0800, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(10.8239, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(10.6509, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(22.2615, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(22.2466, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(29.7402, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(29.8943, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(11.7368, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(11.7550, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(7.6483, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(7.4330, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(2.0859, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(1.9983, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(12.1887, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(12.1226, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(8.1262, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(8.1645, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(16.2888, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(16.2730, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(7.2518, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(7.2264, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(18.0163, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(17.9920, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(17.7536, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(17.9084, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(15.7277, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(15.6494, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(30.2599, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(30.1857, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(29.4958, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(29.5085, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(27.9112, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(27.9138, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(22.7862, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(22.9127, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(8.3637, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(8.4133, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(20.2259, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(20.4175, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(13.7675, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(13.8072, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(13.6803, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(13.6358, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(29.0380, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(29.1893, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(2.0345, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(1.9961, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(7.2510, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(7.2556, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(47.3622, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(47.3580, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(5.5343, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(5.6068, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(30.8870, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(30.9436, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(12.3177, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(12.4010, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(25.8551, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(26.1087, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(6.0668, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(5.9035, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(4.8393, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(4.7604, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(7.5802, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(7.5574, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(5.8172, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(5.7232, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(11.0182, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(11.0585, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(2.3703, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(2.2906, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(7.8038, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(7.6842, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(9.5921, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(9.6234, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(5.9503, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(5.9706, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(21.8846, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(22.0400, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(3.5087, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(3.3972, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(18.4459, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(18.5390, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(9.4380, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(9.4173, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(10.3815, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(10.2920, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(9.9513, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(10.0243, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(4.3860, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(4.3890, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(2.6280, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(2.6274, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(5.2656, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(5.1616, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(8.8575, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(8.8690, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(4.4136, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(4.4313, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(8.2058, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(8.2092, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(8.0101, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(7.8954, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(28.1029, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(28.2139, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(20.8283, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(20.9095, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(6.1564, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(6.1435, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(5.5288, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(5.4806, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(6.2693, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(6.3256, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(18.9476, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(18.9012, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(19.4241, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(19.4659, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(10.9383, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(10.9771, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(11.4521, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(11.4322, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(25.0376, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(24.8961, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(8.4064, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(8.4029, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(8.3406, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(8.2333, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(6.3778, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(6.3910, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(16.0753, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(16.1439, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(14.7284, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(14.7034, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(9.8459, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(9.7969, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(5.3266, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(5.2878, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(10.9737, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(10.9609, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(5.1723, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(5.1665, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(7.4249, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(7.5046, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(17.1431, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(17.2593, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(19.7389, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(19.6904, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(13.2653, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(13.3297, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(5.4652, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(5.4001, grad_fn=<MseLossBackward>)
# ...
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(25.2850, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(6.9831, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(7.1066, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(6.6533, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(6.7381, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(3.3174, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(3.3850, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(15.3992, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(15.3584, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(14.4811, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(14.5118, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(8.8969, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(8.8319, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(23.4231, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(23.1854, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(5.4247, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(5.3427, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(26.4922, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(26.3610, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(6.2400, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(6.2133, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(1.4959, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(1.5959, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(27.1693, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(27.0850, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(7.6071, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(7.7011, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(10.0824, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(9.9851, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(13.1648, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(12.9909, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(19.5957, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(19.4076, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(17.2572, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(17.0201, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(6.3889, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(6.2886, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(14.2329, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(13.7298, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(8.0612, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(8.3877, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(10.5698, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(11.0928, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(33.2578, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(32.9028, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(7.1252, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(7.8550, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(11.7488, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# len of loss  tensor(15.0616, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(8.9351, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(8.9804, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(22.2957, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(22.3530, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(11.0582, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(11.0440, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(6.8214, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(6.8345, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(19.2532, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(19.2511, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(32.1876, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(32.1878, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(39.9916, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(39.9824, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(5.5243, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(5.5269, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(9.1259, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(9.1325, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(4.5876, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(4.5607, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(6.7762, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(6.7569, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(65.9117, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(66.1353, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(2.4287, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(2.3531, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(5.2005, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(5.1153, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(10.1755, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(10.1263, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(4.6476, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(4.6284, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(5.5416, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(5.4822, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(8.2417, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(8.1595, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(12.8109, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(12.8932, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(5.6572, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(5.5441, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(36.2214, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(36.3827, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(5.6441, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(5.6125, grad_fn=<MseLossBackward>)
# the shape of batch_X torch.Size([10, 418])
# the shape of batch_y torch.Size([10])
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(7.7700, grad_fn=<MseLossBackward>)
# the dtype of loss  torch.float32
# the shape of loss torch.Size([])
# len of loss  tensor(7.7563, grad_fn=<MseLossBackward>)
# the shape of batch_X
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
from sklearn.metrics import r2_score

metadata = np.load('E:/metadata数据集/new_bigmetadata/australian/query_time/8australian30_big_metadata30.npy')
net2 = nets[0]
# X = metadata[:, 0:396]
# y = metadata[:, 396]
X = metadata[:, 0:418]
y = metadata[:, 418]
y=y*100
print(y.shape)
X_tensor = torch.from_numpy(X)
y_tensor = torch.from_numpy(y)
X_tensor = X_tensor.float()
y_tensor = y_tensor.float()
out = net2(X_tensor)
print(out.size())
pred = out.detach().numpy()
print(pred.shape)
print(pred[:,0].shape)
# print(predict)
# print(accuracy_score(y, predict))
print(r2_score(y, pred[:,0]))
# Out:
# (27000,)
# torch.Size([27000, 1])
# (27000, 1)
# (27000,)
# -0.00025905524284675074
